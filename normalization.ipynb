# %%
import pandas as pd
from IPython.display import display
f = pd.read_excel('employee_data.xlsx')
MonthlySalary = f ['Monthly Salary']
YearsAtCompany = f ['Years at Company']
JobSatisfaction = f ['Job Satisfaction']
CommuteTime = f ['Commute Time']
columns = ['Monthly Salary','Years at Company','Job Satisfaction','Commute Time']


# Calclation of min max scaling for the given columns
MinMax = f[columns].copy() 
MinMax = (MinMax - MinMax.min()) / (MinMax.max() - MinMax.min())
print ('Min Max scaling:')
display(MinMax)


# Calclation of Z-Score Normalization for the given columns
Z_score = f[columns].copy()
Z_score = (Z_score - Z_score.mean())/Z_score.std()
print ('Z-Score Normalization')
display(Z_score)

# Calclation of Robust Scaling for the given columns
Q1 = f[columns].quantile(0.25)
Q3 = f[columns].quantile(0.75)
IQR = Q3 - Q1
RobustScaling = f[columns].copy()
RobustScaling = (RobustScaling - RobustScaling.median())/IQR
print ('Robust Scaling:')
display(RobustScaling)

# Calclation of Decimal Scaling for the given columns
DecimalScaling = f[columns].copy()
max_value = f[columns].max()
k
for i:
    if max_value / 10 ^ i >= 1:
        i += 1
    else
        k = i - 1
RobustScaling = RobustScaling / 10 ** k
# Out:
#   Cell In[27], line 37
#     for i:
#          ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
from IPython.display import display
f = pd.read_excel(r'D:\dataEngineer\excersise 8\employee_data.xlsx')
MonthlySalary = f ['Monthly Salary']
YearsAtCompany = f ['Years at Company']
JobSatisfaction = f ['Job Satisfaction']
CommuteTime = f ['Commute Time']
columns = ['Monthly Salary','Years at Company','Job Satisfaction','Commute Time']


# Calclation of min max scaling for the given columns
MinMax = f[columns].copy() 
MinMax = (MinMax - MinMax.min()) / (MinMax.max() - MinMax.min())
print ('Min Max scaling:')
display(MinMax)


# Calclation of Z-Score Normalization for the given columns
Z_score = f[columns].copy()
Z_score = (Z_score - Z_score.mean())/Z_score.std()
print ('Z-Score Normalization')
display(Z_score)

# Calclation of Robust Scaling for the given columns
Q1 = f[columns].quantile(0.25)
Q3 = f[columns].quantile(0.75)
IQR = Q3 - Q1
RobustScaling = f[columns].copy()
RobustScaling = (RobustScaling - RobustScaling.median())/IQR
print ('Robust Scaling:')
display(RobustScaling)

# Calclation of Decimal Scaling for the given columns
DecimalScaling = f[columns].copy()
max_value = DecimalScaling.abs().max()
k = {}
for column in columns:
    i = 0
    while max_value[column] / (10 ** i) >=1:
        i += 1
    k[column] = i

for column in columns:
    DecimalScaling[column] = DecimalScaling[column] / (10 ** k[column])
print ('Decimal Scaling:')
display(DecimalScaling)

# Calclation of log transformation for the given columns
import numpy as np
LogTransformation = f[columns].copy()
LogTransformation = np.log(LogTransformation)
print ("log transformation:")
display(LogTransformation)
# Out:
# Min Max scaling:
#    Monthly Salary  Years at Company  Job Satisfaction  Commute Time
# 0        0.000000          0.000000          0.555556      0.100000
# 1        0.045977          0.111111          0.777778      0.166667
# 2        0.080460          0.222222          0.777778      0.233333
# 3        0.022989          0.111111          0.000000      0.666667
# 4        1.000000          1.000000          1.000000      0.000000
# 5        0.034483          0.111111          0.111111      0.833333
# 6        0.057471          0.222222          0.666667      0.266667
# 7        0.011494          0.000000          0.000000      1.000000
# 8        0.137931          0.444444          0.777778      0.333333
# 9        0.195402          0.444444          0.777778      0.166667
# Z-Score Normalization
#    Monthly Salary  Years at Company  Job Satisfaction  Commute Time
# 0       -0.525713         -0.883585          0.030166     -0.820884
# ...
